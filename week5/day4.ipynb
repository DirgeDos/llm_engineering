# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
# %load_ext autoreload
# %autoreload 2
from evaluation import test
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.5450197269026297, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# 🔍 LLM 原始返回JSON： {
#   "accuracy": {
#     "score": 4,
#     "feedback": "The winner is correctly identified as Maxine, aligning with the reference's Maxine Thompson, but the full surname is omitted. Additional details about the role are not verified by the reference."
#   },
#   "completeness": {
#     "score": 4,
#     "feedback": "The answer covers the main fact but omits the surname 'Thompson' which is explicitly present in the reference answer."
#   },
#   "relevance": {
#     "score": 4,
#     "feedback": "The answer directly addresses the question but includes extra information about the job role and meta-text not requested."
#   },
#   "overall_feedback": "The answer is factually correct regarding the winner but lacks the full name precision found in the reference and includes unrequested details."
# }

# %%
eval
# Out:
# AnswerEval(accuracy=ScoreFeedback(score=4.0, feedback="The winner is correctly identified as Maxine, aligning with the reference's Maxine Thompson, but the full surname is omitted. Additional details about the role are not verified by the reference."), completeness=ScoreFeedback(score=4.0, feedback="The answer covers the main fact but omits the surname 'Thompson' which is explicitly present in the reference answer."), relevance=ScoreFeedback(score=4.0, feedback='The answer directly addresses the question but includes extra information about the job role and meta-text not requested.'), overall_feedback='The answer is factually correct regarding the winner but lacks the full name precision found in the reference and includes unrequested details.')

# %%
print(eval.overall_feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer is factually correct regarding the winner but lacks the full name precision found in the reference and includes unrequested details.
# score=4.0 feedback="The winner is correctly identified as Maxine, aligning with the reference's Maxine Thompson, but the full surname is omitted. Additional details about the role are not verified by the reference."
# score=4.0 feedback="The answer covers the main fact but omits the surname 'Thompson' which is explicitly present in the reference answer."
# score=4.0 feedback='The answer directly addresses the question but includes extra information about the job role and meta-text not requested.'
